# %%
from google.colab import files
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c54ca9a-c8db-4db0-86cf-b89b4e6e63e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c54ca9a-c8db-4db0-86cf-b89b4e6e63e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("nba.csv")

# %%
df.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail(5)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.max()
# Out:
# <ipython-input-49-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Number          99.0
# Age             40.0
# Weight         307.0
# Salary    25000000.0
# dtype: float64

# %%
df.min()
# Out:
# <ipython-input-50-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Number        0.0
# Age          19.0
# Weight      161.0
# Salary    30888.0
# dtype: float64

# %%
df.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
df.shape
# Out:
# (458, 9)

# %%
df.size
# Out:
# 4122

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
print(df.Age.max())
print(df.Age.min())
print(df.Age.count())
print(df.Age.std())
print(df.Age.quantile(0.25))
# Out:
# 40.0
# 19.0
# 457
# 4.404016424405833
# 24.0

# %%
groupheight = df.groupby(df['Height'])

# %%
groupheight.get_group('5-11')
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 22   Shane Larkin   Brooklyn Nets     0.0       PG  23.0   5-11   175.0
# 130  Phil Pressey    Phoenix Suns    25.0       PG  25.0   5-11   175.0
# 203     Ty Lawson  Indiana Pacers    10.0       PG  28.0   5-11   195.0
#
#             College     Salary AgeGroup
# 22       Miami (FL)  1500000.0    19-24
# 130        Missouri    55722.0    25-30
# 203  North Carolina   211744.0    25-30

# %%
df.Age.value_counts()
# Out:
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 20.0    19
# 21.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: Age, dtype: int64

# %%
bins = [19,25,31,36,40]
labels = ['19-24','25-30','31-35','36-40']
df['AgeGroup'] = pd.cut(df['Age'],bins=bins,labels=labels,right=False)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary AgeGroup
# 0                Texas  7730337.0    25-30
# ...

# %%
df.groupby('AgeGroup')['Salary'].mean()
# Out:
# AgeGroup
# 19-24    2.706212e+06
# 25-30    5.895838e+06
# 31-35    6.662026e+06
# 36-40    3.847918e+06
# Name: Salary, dtype: float64

# %%
df.groupby('AgeGroup')['Salary'].describe()
# Out:
#           count          mean           std       min        25%        50%  \
# AgeGroup
# 19-24     150.0  2.706212e+06  3.188468e+06   30888.0   960457.0  1654380.0
# 25-30     207.0  5.895838e+06  5.535586e+06   55722.0  1100602.0  4000000.0
# 31-35      67.0  6.662026e+06  6.281446e+06  200600.0  2092835.5  4500000.0
# 36-40      19.0  3.847918e+06  5.516191e+06  222888.0   947276.0  2814000.0
#
#                 75%         max
# AgeGroup
# 19-24     3095650.0  16407501.0
# 25-30     9106741.5  22359364.0
# 31-35     9697402.5  22970500.0
# 36-40     3815259.5  25000000.0

# %%
salarylist = list(df.groupby('AgeGroup')['Salary'])
salarylist
# Out:
# [('19-24',
#   3       1148640.0
#   6       1170960.0
#   8       1824360.0
#   9       3431040.0
#   10      2569260.0
#             ...
#   446    12000000.0
#   447     1175880.0
#   449     1348440.0
#   452     2239800.0
#   454      900000.0
#   Name: Salary, Length: 154, dtype: float64),
#  ('25-30',
#   0       7730337.0
#   1       6796117.0
#   2             NaN
#   4       5000000.0
#   5      12000000.0
#             ...
#   450     2050000.0
#   451      981348.0
#   453     2433333.0
#   455     2900000.0
#   456      947276.0
#   Name: Salary, Length: 212, dtype: float64),
#  ('31-35',
#   19      6300000.0
#   31      1635476.0
#   33     22875000.0
#   34      7402812.0
#   43       947276.0
#             ...
#   375    13000000.0
#   394     4345000.0
#   413     3750000.0
#   415     3135000.0
#   434     5016000.0
#   Name: Salary, Length: 68, dtype: float64),
#  ('36-40',
#   46            NaN
#   72      2900000.0
#   93      5675000.0
#   101     3376000.0
# ...
